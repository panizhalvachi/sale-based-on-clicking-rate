# %%
host = '127.0.0.1'

port = 8080

url = f'http://{host}:{port}/invocations'

headers = {
    'Content-Type': 'application/json',
}
import pandas as pd
import pandas as pd
import pipeline
import requests
import argparse
data = pd.read_csv('train_dataset.csv')
test_data = data.iloc[1:5]
http_data = test_data.to_json(orient='split')

r = requests.post(url=url, headers=headers, data=http_data)

print(f'Predictions: {r.text}')
# Out:
# Predictions: {"error_code": "BAD_REQUEST", "message": "Encountered an unexpected error while evaluating the model. Verify that the serialized input Dataframe is compatible with the model for inference.", "stack_trace": "Traceback (most recent call last):\n  File \"C:\\Users\\ASUS\\.conda\\envs\\ML_Project\\lib\\site-packages\\mlflow\\pyfunc\\scoring_server\\__init__.py\", line 306, in transformation\n    raw_predictions = model.predict(data)\n  File \"C:\\Users\\ASUS\\.conda\\envs\\ML_Project\\lib\\site-packages\\mlflow\\pyfunc\\__init__.py\", line 605, in predict\n    return self._model_impl.predict(data)\n  File \"C:\\Users\\ASUS\\.conda\\envs\\ML_Project\\lib\\site-packages\\mlflow\\pytorch\\__init__.py\", line 748, in predict\n    inp_data = data.values.astype(np.float32)\nValueError: could not convert string to float: '2020-08-04 01:47:40'\n"}
